# %%
import pandas as pd
import seaborn as sns

# %%
m_df = pd.read_csv('/Users/ana/Desktop/marketing.csv') #Took ages to load

# %%
m_df.shape
# Out:
# (10910, 27)

# %%
m_df.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %%
m_df["income"].hist()
# Out:
# <Axes: >

# %%
m_df["customer_lifetime_value"].hist()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer

# %%
scaler = MinMaxScaler()

# %%
m_df["income"]
# Out:
# 0        48029
# 1            0
# 2        22139
# 3        49078
# 4        23675
#          ...
# 10905        0
# 10906    61146
# 10907    39837
# 10908    64195
# 10909        0
# Name: income, Length: 10910, dtype: int64

# %%
m_df["varA"] = scaler.fit_transform(m_df[["income"]])

# %%
m_df["varA"].hist()
# Out:
# <Axes: >

# %%
scaler = StandardScaler()

# %%
m_df["varB"] = scaler.fit_transform(m_df[["customer_lifetime_value"]])

# %%
m_df["varB"].mean()
# Out:
# -1.426295684064729e-16

# %%
m_df["varB"].std()
# Out:
# 1.000045832664961

# %%
#Encoding categorical data

# %%
categorical_df = m_df.select_dtypes(include = 'category')

# %%
numerical_df = m_df.select_dtypes(include = 'number')

# %%
unique_categories = m_df['employmentstatus'].unique()
print(unique_categories)
# Out:
# ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']

# %%
numerical_df.varA.unique()
# Out:
# array([0.48038127, 0.        , 0.22143207, ..., 0.6115762 , 0.3984457 ,
#        0.64207199])

# %%
numerical_df.varB.unique()
# Out:
# array([-0.46610505, -0.84094593,  1.00652314, ..., -0.40071025,
#         2.30582467,  0.5742732 ])

# %%
nominals_df = pd.get_dummies(unique_categories[["Employed","Unemployed", "Mecial Leave", "Disabled", "Retired"]], dtype=int)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 nominals_df = pd.get_dummies(unique_categories[["Employed","Unemployed", "Mecial Leave", "Disabled", "Retired"]], dtype=int)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
unique_categories[["Employed","Unemployed", "Mecial Leave", "Disabled", "Retired"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 unique_categories[["Employed","Unemployed", "Mecial Leave", "Disabled", "Retired"]]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
